# %%
import pandas as pd
import seaborn as sns

# %%
import pandas as pd
sn=pd.read_csv("TripAdvisor_RestauarantRecommendation.csv")
sn
# Out:
#                                Name                         Street Address  \
# 0     Betty Lou's Seafood and Grill                       318 Columbus Ave
# 1                 Coach House Diner                          55 State Rt 4
# 2                  Table Talk Diner                    2521 South Rd Ste C
# 3                       Sixty Vines                       3701 Dallas Pkwy
# 4                      The Clam Bar                      3914 Brewerton Rd
# ...                             ...                                    ...
# 3057     Indigo Kitchen & Ale House                       2902 164th St SW
# 3058                  City Vineyard                        233 West Street
# 3059             BRIO Tuscan Grille                      3710 US Highway 9
# 3060          Maywood Pancake house                      92 W Pleasant Ave
# 3061                  Porto Leggero  Harborside Financial Center - Plaza 5
#
#                           Location  \
# ...

# %%
sn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3062 entries, 0 to 3061
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              3062 non-null   object
#  1   Street Address    3062 non-null   object
#  2   Location          3062 non-null   object
#  3   Type              3049 non-null   object
#  4   Reviews           3062 non-null   object
#  5   No of Reviews     3062 non-null   object
#  6   Comments          2447 non-null   object
#  7   Contact Number    3062 non-null   object
#  8   Trip_advisor Url  3062 non-null   object
#  9   Menu              3062 non-null   object
#  10  Price_Range       3062 non-null   object
# dtypes: object(11)
# memory usage: 263.3+ KB

# %%
sn.describe()
# Out:
#                    Name   Street Address                   Location  \
# count              3062             3062                       3062
# unique             2641             2814                       2653
# top     Texas Roadhouse  3333 Bristol St  Costa Mesa, CA 92626-1873
# freq                 13                8                          8
#
#                                                 Type           Reviews  \
# count                                           3049              3062
# unique                                           669                 6
# top      Italian, Vegetarian Friendly, Vegan Options  4.5 of 5 bubbles
# freq                                             137              1956
#
#        No of Reviews                                           Comments  \
# count           3062                                               2447
# unique           811                                               2291
# ...

# %%
sn.count()
# Out:
# Name                3062
# Street Address      3062
# Location            3062
# Type                3049
# Reviews             3062
# No of Reviews       3062
# Comments            2447
# Contact Number      3062
# Trip_advisor Url    3062
# Menu                3062
# Price_Range         3062
# dtype: int64

# %%
sn=sn.drop(['Name','Street Address','Contact Number','Type'],axis=1)
sn
# Out:
#                           Location           Reviews No of Reviews  \
# 0     San Francisco, CA 94133-3908  4.5 of 5 bubbles   243 reviews
# 1        Hackensack, NJ 07601-6337    4 of 5 bubbles    84 reviews
# 2      Poughkeepsie, NY 12601-5476    4 of 5 bubbles   256 reviews
# 3             Plano, TX 75093-7777  4.5 of 5 bubbles   235 reviews
# 4               Syracuse, NY 13212    4 of 5 bubbles   285 reviews
# ...                            ...               ...           ...
# 3057       Lynnwood, WA 98087-3201  4.5 of 5 bubbles   198 reviews
# 3058       New York City, NY 10013  4.5 of 5 bubbles   374 reviews
# 3059       Freehold, NJ 07728-4801    4 of 5 bubbles   211 reviews
# 3060        Maywood, NJ 07607-1336    4 of 5 bubbles    87 reviews
# 3061         Jersey City, NJ 07311  4.5 of 5 bubbles   183 reviews
#
#                                                Comments  \
# 0                                                   NaN
# ...

# %%
sn.dropna(inplace=True)

# %%
sn.isnull().sum()
# Out:
# Location            0
# Reviews             0
# No of Reviews       0
# Comments            0
# Trip_advisor Url    0
# Menu                0
# Price_Range         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
sn["Location"]=le.fit_transform(sn["Location"])
sn["Reviews"]=le.fit_transform(sn["Reviews"])
sn["No of Reviews"]=le.fit_transform(sn["No of Reviews"])
sn["Comments"]=le.fit_transform (sn["Comments"])
sn["Trip_advisor Url"]=le.fit_transform(sn["Trip_advisor Url"])
sn["Menu"]=le.fit_transform(sn["Menu"])
sn["Price_Range"]=le.fit_transform(sn["Price_Range"])
sn
# Out:
#       Location  Reviews  No of Reviews  Comments  Trip_advisor Url  Menu  \
# 0         2068        3            272      2291              2514     0
# 1          860        2            745       167               933     0
# 2         1741        2            286      1787              1388   144
# 3         1714        3            263      1113              1904   540
# 4         2386        2            318       268              1544     0
# ...        ...      ...            ...       ...               ...   ...
# 3057      1317        3            205      1934              2261     0
# 3058      1426        3            422       184              2571     0
# 3059       785        2            237      1850               908   203
# 3060      1322        2            758      1346               984   317
# 3061      1047        3            189       350               962     0
#
#       Price_Range
# 0               1
# 1               1
# 2               1
# ...

# %%
x=sn.iloc[:,0:7]
x
# Out:
#       Location  Reviews  No of Reviews  Comments  Trip_advisor Url  Menu  \
# 0         2068        3            272      2291              2514     0
# 1          860        2            745       167               933     0
# 2         1741        2            286      1787              1388   144
# 3         1714        3            263      1113              1904   540
# 4         2386        2            318       268              1544     0
# ...        ...      ...            ...       ...               ...   ...
# 3057      1317        3            205      1934              2261     0
# 3058      1426        3            422       184              2571     0
# 3059       785        2            237      1850               908   203
# 3060      1322        2            758      1346               984   317
# 3061      1047        3            189       350               962     0
#
#       Price_Range
# 0               1
# 1               1
# 2               1
# ...

# %%
y=sn.iloc[:,6]
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3057    1
# 3058    1
# 3059    1
# 3060    1
# 3061    2
# Name: Price_Range, Length: 3062, dtype: int32

# %%
from matplotlib import pyplot as plt
plt.hist(sn["Menu"],rwidth=0.80)
plt.title("Histogram")
plt.xlabel("Menu")
plt.ylabel("Price_Range")
plt.show()

# %%
sn.dtypes
# Out:
# Location            int32
# Reviews             int32
# No of Reviews       int32
# Comments            int32
# Trip_advisor Url    int32
# Menu                int32
# Price_Range         int32
# dtype: object

# %%
sns.heatmap(sn.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(sn)

# %%
sns.distplot(sn['Location'])
# Out:
# C:\Users\neeth\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Location', ylabel='Density'>

# %%
sns.distplot(sn['Location'],kde=False)
# Out:
# C:\Users\neeth\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Location'>

# %%
sns.distplot(sn['Location'],kde=False,bins=10)
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
sns.jointplot(x='Reviews',y='Location',data=sn,kind='hex')

# %%
sns.jointplot(x='Reviews',y='Location',data=sn,kind='reg')

# %%
sns.jointplot(x='Reviews',y='Location',data=sn,kind='scatter')

# %%
sns.jointplot(x='Reviews',y='Location',data=sn,kind='hist')

# %%
sns.countplot('Price_Range',data=sn)
# Out:
# C:\Users\neeth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price_Range', ylabel='count'>

# %%
sns.countplot(y='Price_Range',data=sn)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Price_Range'>

# %%
sns.barplot(x='Reviews',y='Price_Range',data=sn)
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='Price_Range'>

# %%
sns.boxplot('Menu','Location',data=sn)
# Out:
# C:\Users\neeth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Menu', ylabel='Location'>

# %%
sns.boxplot(x='Price_Range',y='Location',data=sn)
# Out:
# <AxesSubplot:xlabel='Price_Range', ylabel='Location'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(random_state=0)
lr.fit(x_train,y_train)
# Out:
# C:\Users\neeth\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn import metrics
LR=metrics.accuracy_score(y_test,y_pred)
LR
# Out:
# 0.7864838393731636

# %%
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier()
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn import metrics
DT=metrics.accuracy_score(y_test,y_pred)
DT
# Out:
# 0.7864838393731636

# %%
from sklearn.ensemble import RandomForestClassifier
lr=RandomForestClassifier(n_estimators=3,random_state=0)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
from sklearn import metrics
RF=metrics.accuracy_score(y_test,y_pred)
RF
# Out:
# 0.9970617042115573

# %%
from sklearn.svm import SVC
dc=SVC(kernel='linear')
dc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=dc.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
from sklearn import metrics
SR=metrics.accuracy_score(y_test,y_pred)
SR
# Out:
# 0.9970617042115573

# %%
from sklearn.neighbors import KNeighborsClassifier
KNC=KNeighborsClassifier(n_neighbors=5)

# %%
KNC=KNC.fit(x_train,y_train)
KNC
# Out:
# KNeighborsClassifier()

# %%
y_pred=KNC.predict(x_test)
y_pred
# Out:
# C:\Users\neeth\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn import metrics
KN=metrics.accuracy_score(y_pred,y_test)
KN
# Out:
# 0.761998041136141

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
GN=GaussianNB()
GN.fit(x_train,y_train)
y_pred=GN.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
from sklearn import metrics
NB=metrics.accuracy_score(y_test,y_pred)
NB
# Out:
# 0.9990205680705191

# %%
model=pd.DataFrame({
    'model':['logisticRegression','DecisionTreeClassifier','RandomForestClassifier','svr','kn','NB'],
    'accuracyscore':[LR,DT,RF,SR,KN,NB]
})
model
sns.barplot(x='accuracyscore',y='model',data=model)
model.sort_values(by='accuracyscore',ascending=False)
# Out:
#                     model  accuracyscore
# 5                      NB       0.999021
# 2  RandomForestClassifier       0.997062
# 3                     svr       0.997062
# 0      logisticRegression       0.786484
# 1  DecisionTreeClassifier       0.786484
# 4                      kn       0.761998

# %%
#Conclusion
 In this project trip advisor we can predict accuracy using classification Algorithm .
    The best aacuracy prediction is Random Forest Classifier and SVC.
